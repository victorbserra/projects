# %%
import time
from crawl4ai.web_crawler import WebCrawler

# %%
crawler = WebCrawler()
crawler.warmup()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
url = r"https://www.idealista.it/vendita-case/milano-milano/"
result = crawler.run(url)
# Out:
# [LOG] 🚀 Crawling done for https://www.idealista.it/vendita-case/milano-milano/, success: True, time taken: 4.20 seconds
# [ERROR] 🚫 Failed to crawl https://www.idealista.it/vendita-case/milano-milano/, error: can only concatenate str (not "NoneType") to str

# %%
print(result.markdown)
# Out:
# ## Leilões Online e Presenciais de Veículos, Imóveis, Materiais e Judiciais.
#
#   * Minha Conta
#   * Como Participar
#   * Receba novidades
#   * Blog
#   * Quero vender
#   * Consultar Nota de venda
#   * ...
#     * Consutar Nota de venda
#
#   * Minha Conta
#   * Como Participar
#   * Receba novidades
#   * Blog
#   * **Telefones e Locais**
#   * **Contato**
#   * **Ouvidoria**
#   * **Dúvidas**
#   * **Consultar Nota de venda**
#
# Cadastre-se  Entrar
#
# E-mail
#
# Senha
#
# Novo no site?Cadastre-se aqui
#
# Entrar
#
# esqueci a senha
#
#   * Cadastre-se
#   * Minha Conta
#   * Como Participar
#   * Receba novidades
#   * Blog
#   * **Quero vender**
#   * **Telefones e Locais**
#   * **Contato**
#   * **Ouvidoria**
#   * **Dúvidas**
#   * **Consultar Nota de venda**
#
# ![\\"Leilões](\\"/imagens/logo-sodre-santoro.png?v=1\\"/)
#
# ![\\"Entrar\\"](\\"/imagens/user.png\\")
#
# Buscar
#
# \+ ver todos os lotes \+ ver todos os lotes
#
# ![\\"Logo](\\"/imagens/logo-inverso.png\\")
# ...
